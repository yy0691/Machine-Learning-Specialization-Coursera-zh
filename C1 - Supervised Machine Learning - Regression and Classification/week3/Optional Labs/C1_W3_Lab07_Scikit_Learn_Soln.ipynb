# %% [markdown]
# # 未评分实验：使用 Scikit-Learn 的逻辑回归

# %% [markdown]
# ## 目标
# 在本实验中，您将：
# - 使用 scikit-learn 训练逻辑回归模型。

# %% [markdown]
# ## 数据集
# 让我们从之前使用的相同数据集开始。

# %%
import numpy as np

X = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y = np.array([0, 0, 0, 1, 1, 1])

# %% [markdown]
# ## 拟合模型
#
# 下面的代码从 scikit-learn 导入[逻辑回归模型](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html#sklearn.linear_model.LogisticRegression)。您可以通过调用 `fit` 函数在训练数据上拟合此模型。

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression()
lr_model.fit(X, y)
# Out:
# LogisticRegression()

# %% [markdown]
# ## 进行预测
#
# 您可以通过调用 `predict` 函数查看此模型所做的预测。

# %%
y_pred = lr_model.predict(X)

print("Prediction on training set:", y_pred)
# Out:
# Prediction on training set: [0 0 0 1 1 1]

# %% [markdown]
# ## 计算准确率
#
# 您可以通过调用 `score` 函数计算此模型的准确率。

# %%
print("Accuracy on training set:", lr_model.score(X, y))
# Out:
# Accuracy on training set: 1.0
