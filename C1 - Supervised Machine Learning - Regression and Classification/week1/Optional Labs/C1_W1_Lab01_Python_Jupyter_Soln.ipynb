# %% [markdown]
# # 可选实验：Python 和 Jupyter Notebook 简介
# 欢迎来到第一个可选实验！
# 可选实验可用于：
# - 提供信息 - 就像这个 notebook
# - 通过实践示例强化课程材料
# - 提供在评分实验中使用的例程的工作示例

# %% [markdown]
# ## 目标
# 在本实验中，您将：
# - 简要了解 Jupyter notebooks
# - 浏览 Jupyter notebooks
# - 学习 markdown 单元格和代码单元格的区别
# - 练习一些基本的 Python

# %% [markdown]
# 熟悉 Jupyter notebooks 最简单的方法是使用上方帮助菜单中的导览：

# %% [markdown]
# <figure>
#     <center> <img src="./images/C1W1L1_Tour.PNG"  alt='missing' width="400"  ><center/>
# <figure/>

# %% [markdown]
# Jupyter notebooks 在本课程中使用两种类型的单元格。像这样包含文档的单元格称为 `Markdown 单元格`。该名称来源于单元格中使用的简单格式化语言。您不需要创建 markdown 单元格。了解下面图形中显示的 `单元格下拉菜单` 很有用。有时，单元格可能会处于错误的模式，您可能需要将其恢复到正确的状态：

# %% [markdown]
# <figure>
#    <img src="./images/C1W1L1_Markdown.PNG"  alt='missing' width="400"  >
# <figure/>

# %% [markdown]
# 另一种类型的单元格是 `代码单元格`，您将在其中编写代码：

# %%
# 这是一个 '代码' 单元格
print("This is  code cell")
# Out:
# This is  code cell

# %% [markdown]
# ## Python
# 您可以在代码单元格中编写代码。
# 要运行代码，请选择单元格，然后：
# - 按住 shift 键并按下 'enter' 或 'return'
# - 点击上方的 'run' 箭头
# <figure>
#     <img src="./images/C1W1L1_Run.PNG"  width="400"  >
# <figure/>

# %% [markdown]
# ### Print 语句
# Print 语句通常使用 Python f-string 风格。
# 尝试在下面的单元格中创建您自己的 print 语句。
# 尝试两种运行单元格的方法。

# %%
# print 语句
variable = "right in the strings!"
print(f"f strings allow you to embed variables {variable}")
# Out:
# f strings allow you to embed variables right in the strings!

# %% [markdown]
# # 恭喜！
# 您现在知道如何在 Jupyter Notebook 中操作了。
